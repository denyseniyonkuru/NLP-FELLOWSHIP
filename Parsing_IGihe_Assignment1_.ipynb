# %% [markdown]
# <a href="https://colab.research.google.com/github/denyseniyonkuru/NLP-FELLOWSHIP/blob/week1/Parsing_IGihe_Assignment1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

from bs4 import BeautifulSoup
import pandas as pd

# %%
#Get all the available captures since jan-2022

# %%
links =  requests.get('http://archive.org/wayback/available?url=igihe.com&timestamp=20220123')

# %%
links.json()
# Out:
# {'url': 'igihe.com',
#  'archived_snapshots': {'closest': {'status': '200',
#    'available': True,
#    'url': 'http://web.archive.org/web/20220123092659/https://igihe.com/',
#    'timestamp': '20220123092659'}},
#  'timestamp': '20220123'}

# %%
snap = []
err = []
for month in range(10):
    for day in range(31):
        link = requests.get('http://archive.org/wayback/available?url=igihe.com&timestamp=2022{:02d}{:02d}'.format(month, day))
        try:
            if link.json()['archived_snapshots']['closest']['available']:
                snap.append(link.json()['archived_snapshots']['closest']['url'])
        except KeyError:
            err.append(link.json())
            break

# %%
len(snap)
# Out:
# 211

# %%
snaps_r  = set(snap)

# %%
len(snaps_r)
# Out:
# 126

# %%
snap_r = list(snaps_r)

# %%
len(snap_r)
# Out:
# 126

# %%
str(snap_r[0])
# Out:
# 'http://web.archive.org/web/20220224235741/https://www.igihe.com/'

# %%
b = requests.get(url=str(snap_r[0]))

# %%
b.content
# Out:
# b'<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN">\n<html lang="rw">\n<head><script src="//archive.org/includes/analytics.js?v=cf34f82" type="text/javascript"></script>\n<script type="text/javascript">window.addEventListener(\'DOMContentLoaded\',function(){var v=archive_analytics.values;v.service=\'wb\';v.server_name=\'wwwb-app222.us.archive.org\';v.server_ms=257;archive_analytics.send_pageview({});});</script>\n<script type="text/javascript" src="/_static/js/bundle-playback.js?v=U25-Dms9" charset="utf-8"></script>\n<script type="text/javascript" src="/_static/js/wombat.js?v=UHAOicsW" charset="utf-8"></script>\n<script type="text/javascript">\n  __wm.init("http://web.archive.org/web");\n  __wm.wombat("https://www.igihe.com/","20220224235741","http://web.archive.org/","web","/_static/",\n\t      "1645747061");\n</script>\n<link rel="stylesheet" type="text/css" href="/_static/css/banner-styles.css?v=fantwOh2" />\n<link rel="stylesheet" type="text/css" href="/_static/css/iconochive.css?v=qtvMKcIJ" />\n<!-- End Wayback Rewrite JS Include -->\n\n<title>IGIHE | Amakuru, Politiki, Ubukungu, Diaspora, Imikino, Muzika &amp; Videos...</title>\n<meta name="google-site-verification" content="UMjExRPxoA9FNY2SQ3Jry45E2V83ukmcDLl78RxoHiE"/>\n<script async src="http://web.archive.org/web/20220224235741js_/https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-8563519530061720" crossorigin="anonymous"></script>\n<meta name="description" content="Amakuru, Politiki, Ubukungu, Diaspora, Imikino, Muzika &amp; Videos..."/>\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8">\n<meta http-equiv="X-UA-Compatible" content="IE=9; IE=8; IE=7; IE=edge">\n<meta name="keywords" content="cloud hosting, rwanda news, igihe, insurance, auto express, paul kagame, kigali, news, east africa, lead generation, west palm beach accident attorney, lawyers near me car accident, accident lawyer san antonio, cloud hosting providers, global trade management"/>\n<meta name="viewport" content="width=device-width, initial-scale=1">\n<meta property="fb:pages" content="171343222113"/>\n<script type="text/javascript">\t\n\t\tif(screen.width <= 700) {\n\t\t\twindow.location = "http://web.archive.org/web/20220224235741/https://mobile.igihe.com/";\n\t\t}\t\n\t</script>\n<link rel="shortcut icon" href="/web/20220224235741im_/https://www.igihe.com/squelettes/igihe_imgs/fav-icon.png">\n<meta name="generator" content="Bootply">\n<link type="text/css" href="http://web.archive.org/web/20220224235741cs_/https://igihe.com/squelettes/v5css/bootstrap.css" rel="stylesheet">\n<script type="text/javascript" src="http://web.archive.org/web/20220224235741js_/https://igihe.com/squelettes/v5js/jquery.min.js"></script>\n<script type="text/javascript" src="http://web.archive.org/web/20220224235741js_/https://igihe.com/squelettes/v5js/bootstrap.min.js"></script>\n<script type="text/javascript" src="http://web.archive.org/web/20220224235741js_/https://igihe.com/squelettes/v5js/clockwise.js"></script>\n<script type="text/javascript" src="http://web.archive.org/web/20220224235741js_/https://igihe.com/squelettes/v5js/scrollingdiv.js?t=6"></script>\n<link rel="stylesheet" type="text/css" href="http://web.archive.org/web/20220224235741cs_/https://igihe.com/squelettes/v5css/breakingNews.css?t=986554233">\n<script type="text/javascript" src="http://web.archive.org/web/20220224235741js_/https://igihe.com/squelettes/v5js/breakingNews.js"></script>\n<script type="text/javascript" src="http://web.archive.org/web/20220224235741js_/https://igihe.com/v5carouselengine/amazingcarousel.js"></script>\n<link rel="stylesheet" type="text/css" href="http://web.archive.org/web/20220224235741cs_/https://igihe.com/v5carouselengine/initcarousel-1.css?t=8">\n<script type="text/javascript" src="http://web.archive.org/web/20220224235741js_/https://igihe.com/v5carouselengine/initcarousel-1.js"></script>\n<link rel="stylesheet" type="text/css" href="http://web.archive.org/web/2022 ...

# %%
BeautifulSoup(str(b.content), "html.parser").prettify()
# Out:
# 'b\'\n<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN">\n\\n\n<html lang="rw">\n \\n\n <head>\n  <script src="//archive.org/includes/analytics.js?v=cf34f82" type="text/javascript">\n  </script>\n  \\n\n  <script type="text/javascript">\n   window.addEventListener(\\\'DOMContentLoaded\\\',function(){var v=archive_analytics.values;v.service=\\\'wb\\\';v.server_name=\\\'wwwb-app222.us.archive.org\\\';v.server_ms=257;archive_analytics.send_pageview({});});\n  </script>\n  \\n\n  <script charset="utf-8" src="/_static/js/bundle-playback.js?v=U25-Dms9" type="text/javascript">\n  </script>\n  \\n\n  <script charset="utf-8" src="/_static/js/wombat.js?v=UHAOicsW" type="text/javascript">\n  </script>\n  \\n\n  <script type="text/javascript">\n   \\n  __wm.init("http://web.archive.org/web");\\n  __wm.wombat("https://www.igihe.com/","20220224235741","http://web.archive.org/","web","/_static/",\\n\\t      "1645747061");\\n\n  </script>\n  \\n\n  <link href="/_static/css/banner-styles.css?v=fantwOh2" rel="stylesheet" type="text/css"/>\n  \\n\n  <link href="/_static/css/iconochive.css?v=qtvMKcIJ" rel="stylesheet" type="text/css"/>\n  \\n\n  <!-- End Wayback Rewrite JS Include -->\n  \\n\\n\n  <title>\n   IGIHE | Amakuru, Politiki, Ubukungu, Diaspora, Imikino, Muzika &amp; Videos...\n  </title>\n  \\n\n  <meta content="UMjExRPxoA9FNY2SQ3Jry45E2V83ukmcDLl78RxoHiE" name="google-site-verification"/>\n  \\n\n  <script async="" crossorigin="anonymous" src="http://web.archive.org/web/20220224235741js_/https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-8563519530061720">\n  </script>\n  \\n\n  <meta content="Amakuru, Politiki, Ubukungu, Diaspora, Imikino, Muzika &amp; Videos..." name="description"/>\n  \\n\n  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>\n  \\n\n  <meta content="IE=9; IE=8; IE=7; IE=edge" http-equiv="X-UA-Compatible"/>\n  \\n\n  <meta content="cloud hosting, rwanda news, igihe, insurance, auto express, paul kagame, kigali, news, east africa, lead generation, west palm beach accident attorney, lawyers near me car accident, accident lawyer san antonio, cloud hosting providers, global trade management" name="keywords">\n   \\n\n   <meta content="width=device-width, initial-scale=1" name="viewport"/>\n   \\n\n   <meta content="171343222113" property="fb:pages">\n    \\n\n    <script type="text/javascript">\n     \\t\\n\\t\\tif(screen.width <= 700) {\\n\\t\\t\\twindow.location = "http://web.archive.org/web/20220224235741/https://mobile.igihe.com/";\\n\\t\\t}\\t\\n\\t\n    </script>\n    \\n\n    <link href="/web/20220224235741im_/https://www.igihe.com/squelettes/igihe_imgs/fav-icon.png" rel="shortcut icon"/>\n    \\n\n    <meta content="Bootply" name="generator"/>\n    \\n\n    <link href="http://web.archive.org/web/20220224235741cs_/https://igihe.com/squelettes/v5css/bootstrap.css" rel="stylesheet" type="text/css"/>\n    \\n\n    <script src="http://web.archive.org/web/20220224235741js_/https://igihe.com/squelettes/v5js/jquery.min.js" type="text/javascript">\n    </script>\n    \\n\n    <script src="http://web.archive.org/web/20220224235741js_/https://igihe.com/squelettes/v5js/bootstrap.min.js" type="text/javascript">\n    </script>\n    \\n\n    <script src="http://web.archive.org/web/20220224235741js_/https://igihe.com/squelettes/v5js/clockwise.js" type="text/javascript">\n    </script>\n    \\n\n    <script src="http://web.archive.org/web/20220224235741js_/https://igihe.com/squelettes/v5js/scrollingdiv.js?t=6" type="text/javascript">\n    </script>\n    \\n\n    <link href="http://web.archive.org/web/20220224235741cs_/https://igihe.com/squelettes/v5css/breakingNews.css?t=986554233" rel="stylesheet" type="text/css"/>\n    \\n\n    <script src="http://web.archive.org/web/20220224235741js_/https://igihe.com/squelettes/v5js/breakingNews.js" type="text/javascript">\n    </script>\n    \\n\n    <script src="http://web.archive.org/web/20220224235741js_/https://igihe.com/v5carouse ...

# %%
#Fetch all the titles and their link from wayback archivr

links_art = []

for lin in snaps_r:
  content = requests.get(url=lin).content
  soup =  BeautifulSoup(content, "html.parser")
  articles = soup.find_all('span', class_="homenews-title")
  links_art.append(articles)

# %%
links_art[0][0].find('a')['href']
# Out:
# 'imikino/football/article/fifa-yahagaritse-kenya-na-zimbabwe-kubera-kwivanga'

# %%
list(snaps_r)[0]
# Out:
# 'http://web.archive.org/web/20220224235741/https://www.igihe.com/'

# %%
#Actual link
wayback_link = []
href_link = []

#Loop all the 184 snapshots
for index, snapshot in enumerate(list(snaps_r)):
  #In each title assign it's snapshop prefix link
  for title in links_art[index]:
    wayback_link.append(snapshot)
    href_link.append(str(title.find('a')['href']))

# %%
len(href_link)
# Out:
# 9198

# %%
df = pd.DataFrame(list(zip(wayback_link, href_link)), columns=['Prefix', 'Title'])

# %%
df.describe()
# Out:
#                                                    Prefix  \
# count                                                9198
# unique                                                126
# top     http://web.archive.org/web/20220224235741/http...
# freq                                                   73
#
#                                                     Title
# count                                                9198
# unique                                               4947
# top     abantu/kubaho/urukundo/article/byiringiro-lagu...
# freq                                                   13

# %%
df.head(10)
# Out:
#                                               Prefix  \
# 0  http://web.archive.org/web/20220224235741/http...
# 1  http://web.archive.org/web/20220224235741/http...
# 2  http://web.archive.org/web/20220224235741/http...
# 3  http://web.archive.org/web/20220224235741/http...
# 4  http://web.archive.org/web/20220224235741/http...
# 5  http://web.archive.org/web/20220224235741/http...
# 6  http://web.archive.org/web/20220224235741/http...
# 7  http://web.archive.org/web/20220224235741/http...
# 8  http://web.archive.org/web/20220224235741/http...
# 9  http://web.archive.org/web/20220224235741/http...
#
#                                                Title
# 0  imikino/football/article/fifa-yahagaritse-keny...
# 1  amakuru/u-rwanda/article/rubavu-utugari-two-mu...
# 2  amakuru/u-rwanda/article/imva-zo-ku-rwibutso-r...
# 3  amakuru/u-rwanda/article/dr-ngirente-yahagarar...
# 4  amakuru/u-rwanda/article/psf-igiye-gukora-impi...
# 5  amakuru/utuntu-n-utundi/article/nyabugogo-yahe...
# 6  imyidagaduro/sinema/article/lindsey-pearlman-w...
# 7  imikino/football/article/apr-fc-na-rayon-sport...
# 8  amakuru/u-rwanda/article/abasenateri-ba-zimbab...
# 9  amakuru/u-rwanda/article/kamonyi-imvura-yateye...

# %%
df.drop_duplicates(subset=['Title'])
# Out:
#                                                  Prefix  \
# 0     http://web.archive.org/web/20220224235741/http...
# 1     http://web.archive.org/web/20220224235741/http...
# 2     http://web.archive.org/web/20220224235741/http...
# 3     http://web.archive.org/web/20220224235741/http...
# 4     http://web.archive.org/web/20220224235741/http...
# ...                                                 ...
# 9177  http://web.archive.org/web/20220222005719/http...
# 9185  http://web.archive.org/web/20220222005719/http...
# 9189  http://web.archive.org/web/20220222005719/http...
# 9190  http://web.archive.org/web/20220222005719/http...
# 9191  http://web.archive.org/web/20220222005719/http...
#
#                                                   Title
# 0     imikino/football/article/fifa-yahagaritse-keny...
# 1     amakuru/u-rwanda/article/rubavu-utugari-two-mu...
# 2     amakuru/u-rwanda/article/imva-zo-ku-rwibutso-r...
# 3     amakuru/u-rwanda/article/dr-ngirente-yahagarar...
# 4     amakuru/u-rwanda/article/psf-igiye-gukora-impi...
# ...                                                 ...
# 9177  amakuru/u-rwanda/article/cabo-delgado-ubutasi-...
# 9185  amakuru/utuntu-n-utundi/article/ibiraro-bitang...
# 9189  ubukerarugendo/article/hasobanuwe-icyo-hot-air...
# 9190  amakuru/u-rwanda/article/gen-muhoozi-yiyamye-r...
# 9191  imyemerere/article/umuriro-watse-muri-zion-tem...
#
# [4947 rows x 2 columns]

# %%
content = requests.get(df['Prefix'][0]+df['Title'][0]).content
raw_content = BeautifulSoup(content, 'html.parser')

# %%
BeautifulSoup(str(raw_content.find_all('div', class_="fulltext margintop10"))).find_all('p')[1]
# Out:
# <p>Zimbabwe ihanwe nyuma y’uko Guverinoma yanze kuvana ukuboko kwayo mu miyoborere y’ishyirahamwe ry’umupira w’amaguru muri icyo gihugu, dore ko iherutse gushyiraho ubuyobozi bushya.</p>

# %%
str(raw_content)
# Out:
# '<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN">\n\n<html lang="rw" prefix="og: https://ogp.me/ns#">\n<head><script src="//archive.org/includes/analytics.js?v=cf34f82" type="text/javascript"></script>\n<script type="text/javascript">window.addEventListener(\'DOMContentLoaded\',function(){var v=archive_analytics.values;v.service=\'wb\';v.server_name=\'wwwb-app201.us.archive.org\';v.server_ms=236;archive_analytics.send_pageview({});});</script>\n<script charset="utf-8" src="/_static/js/bundle-playback.js?v=U25-Dms9" type="text/javascript"></script>\n<script charset="utf-8" src="/_static/js/wombat.js?v=UHAOicsW" type="text/javascript"></script>\n<script type="text/javascript">\n  __wm.init("http://web.archive.org/web");\n  __wm.wombat("https://www.igihe.com/imikino/football/article/fifa-yahagaritse-kenya-na-zimbabwe-kubera-kwivanga","20220225012334","http://web.archive.org/","web","/_static/",\n\t      "1645752214");\n</script>\n<link href="/_static/css/banner-styles.css?v=fantwOh2" rel="stylesheet" type="text/css"/>\n<link href="/_static/css/iconochive.css?v=qtvMKcIJ" rel="stylesheet" type="text/css"/>\n<!-- End Wayback Rewrite JS Include -->\n<title>FIFA yahagaritse Kenya na Zimbabwe kubera kwivanga  - IGIHE.com</title>\n<base href="http://web.archive.org/web/20220225012334/https://igihe.com/"/>\n<meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>\n<meta content="IE=9; IE=8; IE=7; IE=edge" http-equiv="X-UA-Compatible"/>\n<meta content="Amakuru, Politiki, Ubukungu, Diaspora, Imikino, Muzika &amp; Videos..." name="description">\n<meta content="cloud hosting, rwanda news, igihe, insurance, auto express, paul kagame, kigali, news, east africa, lead generation, west palm beach accident attorney, lawyers near me car accident, accident lawyer san antonio, cloud hosting providers, global trade management" name="keywords">\n<meta content="width=device-width, initial-scale=1" name="viewport"/>\n<meta content="171343222113" property="fb:pages">\n<script type="text/javascript">\t\n\t\tif(screen.width <= 700) {\n\t\t\twindow.location = "http://web.archive.org/web/20220225012334/https://mobile.igihe.com/imikino/football/article/fifa-yahagaritse-kenya-na-zimbabwe-kubera-kwivanga";\n\t\t}\t\n\t</script>\n<link href="/web/20220225012334im_/https://igihe.com/squelettes/igihe_imgs/fav-icon.png" rel="shortcut icon"/>\n<meta content="Bootply" name="generator"/>\n<meta content="website" property="og:type"/>\n<meta content="IGIHE" property="og:site_name"/>\n<meta content="FIFA yahagaritse Kenya na Zimbabwe kubera kwivanga " property="og:title"/>\n<meta content="Ishyirahamwe ry’Umupira w’amaguru ku Isi (FIFA) ryahagaritse Kenya na Zimbabwe kwitabira amarushanwa mpuzamahanga kubera uburyo Guverinoma z’ibyo bihugu zivanze mu mikorere y’inzego z’umupira w’amaguru wabyo." property="og:description"/>\n<meta content="http://web.archive.org/web/20220225012334im_/https://igihe.com/IMG/arton165114.jpg?1645741176" property="og:image"/>\n<meta content="463" property="og:image:width">\n<meta content="330" property="og:image:height">\n<link href="http://web.archive.org/web/20220225012334im_/https://igihe.com/IMG/arton165114.jpg?1645741176" rel="image_src" type="image/jpeg">\n<meta content="imikino/football/article/fifa-yahagaritse-kenya-na-zimbabwe-kubera-kwivanga" property="og:url"/>\n<meta content="kin" property="og:locale"/>\n<meta content="summary_large_image" name="twitter:card"/>\n<meta content="@igihe" name="twitter:site"/>\n<meta content="FIFA yahagaritse Kenya na Zimbabwe kubera kwivanga " name="twitter:title"/>\n<meta content="Ishyirahamwe ry’Umupira w’amaguru ku Isi (FIFA) ryahagaritse Kenya na Zimbabwe kwitabira amarushanwa mpuzamahanga kubera uburyo Guverinoma z’ibyo bihugu zivanze mu mikorere y’inzego z’umupira w’amaguru wabyo." name="twitter:description"/>\n<meta content="@igihe" name="twitter:creator"/>\n<meta content="https://igihe.com/IMG/arton165114.jpg?1645741176" name="twitter:image:src"/>\n<link href="http://w ...

# %%
def get_article_text(link):
  content = requests.get(link).content
  raw_content = BeautifulSoup(content, 'html.parser').find_all('div', class_='fulltext').children()
  tex

# %% [markdown]
# Assignement start here

# %%
def get_article_text(link):
  """This function will extract the content given the link
  
  Args
  ----
  link: str
      link to be passed(link+ title)

  Returns
  -------
  cnts: list 
        list of contents extracted from links 
  """   
  # get all content from the link page
  content = requests.get(link).content
  # extract content of the class: full text
  raw_content =  BeautifulSoup(content, 'html.parser').find_all('div', class_="fulltext margintop10")

  # extract paragraphs 
  raw_content_ = (BeautifulSoup(str(raw_content)).find_all('p'))
  Cnts = []

  # loop through the contents and extract text
  for i in range(len(raw_content_)-1):
    #append text to the created list 
    Cnts.append((raw_content_[i+1]).text)

  return Cnts

# %%
# call the function to extract content
#Sample of first 50 rows will be taken

r = []
sample_50 = df.iloc[:50,:]
# iterate through created dataset 
for i in range(len(sample_50)):
  # create an empty dictianary
  d = {}
  # use the function to extract content 
  u = get_article_text(sample_50['Prefix'][i]+sample_50['Title'][i])

  # extract links from the dataset as values and create an index call links to the empty dictionary 
  d['Links'] = sample_50['Prefix'][i]
  d['Titles'] = sample_50['Title'][i]   # extract title from the dataset as values and create an index call title to the empty dictionary 

  d['Contents'] = u

  # append the dictionary to the create list 
  r.append(d)

# %%
# create a dataframe from a list 
data = pd.DataFrame(r)

# %%
data.head()
# Out:
#                                                Links  \
# 0  http://web.archive.org/web/20220224235741/http...
# 1  http://web.archive.org/web/20220224235741/http...
# 2  http://web.archive.org/web/20220224235741/http...
# 3  http://web.archive.org/web/20220224235741/http...
# 4  http://web.archive.org/web/20220224235741/http...
#
#                                               Titles  \
# 0  imikino/football/article/fifa-yahagaritse-keny...
# 1  amakuru/u-rwanda/article/rubavu-utugari-two-mu...
# 2  amakuru/u-rwanda/article/imva-zo-ku-rwibutso-r...
# 3  amakuru/u-rwanda/article/dr-ngirente-yahagarar...
# 4  amakuru/u-rwanda/article/psf-igiye-gukora-impi...
#
#                                             Contents
# 0  [Zimbabwe ihanwe nyuma y’uko Guverinoma yanze ...
# 1  [Byatangajwe kuwa Kabiri ubwo hatangwaga moto ...
# 2  [Mu gitondo cyo kuri uyu wa kane kuya 24 Gashy...
# 3  [Ni inama ihuza abakuru b’ibihugu na za Guveri...
# 4  [Ubusanzwe urugaga rw’abikorera rwari rufite a...
